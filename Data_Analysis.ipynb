# %%
#Explantory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib as pt
import os
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = 20, 8
import plotly.graph_objs as go
import chart_studio.plotly

# %%
df=pd.read_csv("final.csv")
df
# Out:
#                State          District            Market Variety   Commadity  \
# 0         Chandigarh        Chandigarh  Chandigarh (F&V)   Local  Vegetables
# 1            Gujarat             Dahod             Dahod   Local  Vegetables
# 2            Gujarat  Vadodara(Baroda)          Vadodara   Local  Vegetables
# 3          Karnataka         Davangere         Davangere   Local  Vegetables
# 4          Karnataka           Dharwad           Dharwar   Local  Vegetables
# ...              ...               ...               ...     ...         ...
# 1664556       Kerala         Alappuzha             Aroor   Local  Vegetables
# 1664557       Kerala         Alappuzha         Alappuzha   Local  Vegetables
# 1664558      Haryana      Yamuna Nagar          Sadhaura   Local  Vegetables
# 1664559       Punjab          Amritsar             Rayya  Hybrid  Vegetables
# 1664560  West Bengal        Jalpaiguri  Jalpaiguri Sadar   Local  Vegetables
#
# ...

# %%
df['State_Mean'] = df.groupby(['State']).Tons.transform('mean')
df['Market_Mean'] = df.groupby(['Market']).Tons.transform('mean')
df['State_Price_Mean'] = df.groupby(['State']).Modal_Price.transform('mean')
df['Market_Price_Mean'] = df.groupby(['Market']).Modal_Price.transform('mean')

# %%
State = sns.countplot(y='State', data=df)

# %%
State = sns.countplot(y='Month', data=df)

# %%
plt.figure(figsize=(30,10))
sns.barplot(x=df['State'],y=df['State_Price_Mean'],data=df)

# %%
plt.figure(figsize=(30,10))
sns.barplot(x=df['State'],y=df['State_Mean'],data=df)

# %%
plt.figure(figsize=(30,10))
sns.barplot(x='State',y='Tons',data=df)

# %%
filtered=df[(df.Year == 2020)]

# %%
State = sns.countplot(y='State', data=filtered)

# %%
State = sns.countplot(y='Month', data=filtered)

# %%
plt.figure(figsize=(30,10))
sns.barplot(x=df['State'],y=df['Tons'],data=filtered)

# %%
sns.heatmap(df.corr(), cmap='coolwarm')
