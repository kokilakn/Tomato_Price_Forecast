# %%
#selection of data for model

# %%
import pandas as pd
import numpy as np
import matplotlib as pt
import os
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize'] = 20, 8

# %%
df=pd.read_csv("final.csv")

# %%
#as variety local is more than 90% we only consider local

# %%
df= df[df['Variety'] == 'Local']

# %%
markets=df['Market'].value_counts()

# %%
markets.head(5)
# Out:
# Fatehabad    5333
# Vadhvan      5175
# Boudh        5091
# Kharar       5006
# Ahmedabad    4839
# Name: Market, dtype: int64

# %%
#check the continuity of above markets

# %%
df_Fatehabad=df[df.Market=="Fatehabad"]
df_Vadhvan=df[df.Market=="Vadhvan"]

# %%
sns.barplot(y='Modal_Price',hue='Month',x="Year",data=df_Fatehabad)

# %%
#as data is not continous near 2017 we consider Vadhvan

# %%
sns.barplot(y='Modal_Price',hue='Month',x="Year",data=df_Vadhvan)

# %%
sns.barplot(y='Tons',hue='Month',x="Year",data=df_Vadhvan)

# %%
sns.barplot(y='Modal_Price',x='Month',data=df_Vadhvan)

# %%
sns.barplot(y='Tons',x='Month',data=df_Vadhvan)

# %%
#save data for model
df_Vadhvan.to_csv("Vadhvan.csv")
